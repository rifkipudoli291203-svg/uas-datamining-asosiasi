# %% [markdown]
# # Analisis Pola Pembelian Konsumen Menggunakan Algoritma Apriori Pada Dataset Online Retail
#
# Nama : Muhamad Rifki Pudoli
#
# NIM : 1224160053
#
# Mata Kuliah : Konsep Data Warehouse & Mining
#
# Dosen : Agus Rifaldi, S.Kom
#
# Metode : Association Rule Mining (Apriori)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Business Understanding
#
# ## Latar Belakang
#
# Perusahaan retail menghasilkan data transaksi dalam jumlah besar setiap harinya. Data tersebut dapat dimanfaatkan untuk menemukan pola pembelian pelanggan sehingga perusahaan dapat mengetahui produk apa saja yang sering dibeli secara bersamaan.
#
# ## Tujuan
#
# Menemukan hubungan antar produk menggunakan algoritma Apriori.
#
# ## Manfaat
#
# - Mengetahui pola pembelian pelanggan
# - Membantu strategi promosi
# - Membantu paket bundling produk
# - Meningkatkan penjualan

# %%
df = pd.read_csv("online_retail.csv")

df.head()
df.describe()
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
print("Jumlah Baris :", df.shape[0])
print("Jumlah Kolom :", df.shape[1])
# Out:
# Jumlah Baris : 541909
# Jumlah Kolom : 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# # Data Preparation
#
# Tahapan:
#
# 1. Menghapus missing value
# 2. Menghapus transaksi retur
# 3. Menghapus transaksi cancel
# 4. Membentuk basket transaksi

# %%
df = df.dropna()

# %%
df = df[df['Quantity'] > 0]

# %%
df = df[~df['InvoiceNo'].astype(str).str.startswith('C')]

# %%
print(df.shape)
# Out:
# (397924, 8)

# %%
top_produk = df['Description'].value_counts().head(10)

top_produk
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2028
# REGENCY CAKESTAND 3 TIER              1724
# JUMBO BAG RED RETROSPOT               1618
# ASSORTED COLOUR BIRD ORNAMENT         1408
# PARTY BUNTING                         1397
# LUNCH BAG RED RETROSPOT               1316
# SET OF 3 CAKE TINS PANTRY DESIGN      1159
# LUNCH BAG  BLACK SKULL.               1105
# POSTAGE                               1099
# PACK OF 72 RETROSPOT CAKE CASES       1068
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

top_produk.plot(kind='bar')

plt.title("Top 10 Produk Terlaris")
plt.xlabel("Produk")
plt.ylabel("Jumlah Penjualan")

plt.show()

# %%
basket = (df.groupby(['InvoiceNo','Description'])['Quantity']
            .sum()
            .unstack()
            .reset_index()
            .fillna(0)
            .set_index('InvoiceNo'))

# %%
def encode(x):
    if x <= 0:
        return 0
    else:
        return 1

basket = basket.applymap(encode)

basket.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# ...

# %%
basket = df.groupby('InvoiceNo')['Description'].apply(list)

basket.head()
# Out:
# InvoiceNo
# 536365    [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 536366    [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 536367    [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 536368    [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 536369                           [BATH BUILDING BLOCK WORD]
# Name: Description, dtype: object

# %%
df_sales = df[df['Quantity'] > 0]

# %%
plt.figure(figsize=(10,6))
sns.histplot(
    transaction_quantity[transaction_quantity <= 100],
    bins=25,
    kde=True
)

plt.title('Distribusi Jumlah Produk per Transaksi (≤ 100 Produk)')
plt.xlabel('Jumlah Produk yang Dibeli')
plt.ylabel('Frekuensi Transaksi')

plt.show()

# %%
selected_features = df[['InvoiceNo', 'Description', 'Quantity']]

# %%
price_data = df[df['UnitPrice'] > 0]

# %%
plt.figure(figsize=(10,6))
sns.histplot(
    price_data[price_data['UnitPrice'] <= 50]['UnitPrice'],
    bins=30,
    kde=True
)

plt.title('Distribusi Harga Produk (UnitPrice ≤ 50)')
plt.xlabel('Harga Produk')
plt.ylabel('Frekuensi')
# Out:
# Text(0, 0.5, 'Frekuensi')

# %%
df[['Quantity','UnitPrice']].corr()
# Out:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.001235
# UnitPrice -0.001235   1.000000

# %%
transaction_quantity = df_sales.groupby('InvoiceNo')['Quantity'].sum()

# %%
selected_features.head()
# Out:
#   InvoiceNo                          Description  Quantity
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365                  WHITE METAL LANTERN         6
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6

# %% [markdown]
# # Modeling
#
# Menggunakan Algoritma Apriori

# %%
rules = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=1
)

rules.head()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_itemsets = apriori(
    basket,
    min_support=0.03,
    use_colnames=True
)

frequent_itemsets.head()
# Out:
#     support                       itemsets
# 0  0.039167       (6 RIBBONS RUSTIC CHARM)
# 1  0.035445  (60 TEATIME FAIRY CAKE CASES)
# 2  0.042566   (ALARM CLOCK BAKELIKE GREEN)
# 3  0.033071    (ALARM CLOCK BAKELIKE PINK)
# 4  0.047313    (ALARM CLOCK BAKELIKE RED )

# %%
frequent_itemsets.sort_values(
    by='support',
    ascending=False
).head(10)
# Out:
#      support                              itemsets
# 86  0.106334  (WHITE HANGING HEART T-LIGHT HOLDER)
# 69  0.091929            (REGENCY CAKESTAND 3 TIER)
# 35  0.086319             (JUMBO BAG RED RETROSPOT)
# 58  0.074450                       (PARTY BUNTING)
# 5   0.074180       (ASSORTED COLOUR BIRD ORNAMENT)
# 47  0.069486             (LUNCH BAG RED RETROSPOT)
# 75  0.061826   (SET OF 3 CAKE TINS PANTRY DESIGN )
# 63  0.059290                             (POSTAGE)
# 41  0.056754             (LUNCH BAG  BLACK SKULL.)
# 54  0.055514     (PACK OF 72 RETROSPOT CAKE CASES)

# %%
top_produk = df['Description'].value_counts().head(10)

top_produk.plot(
    kind='bar',
    figsize=(10,5)
)
# Out:
# <Axes: xlabel='Description'>

# %%
rules[['antecedents',
       'consequents',
       'support',
       'confidence',
       'lift']]
# Out:
#                         antecedents  \
# 0          (6 RIBBONS RUSTIC CHARM)
# 1                  (DOTCOM POSTAGE)
# 2          (6 RIBBONS RUSTIC CHARM)
# 3          (JAM MAKING SET PRINTED)
# 4          (6 RIBBONS RUSTIC CHARM)
# ...                             ...
# 3479    (CHARLOTTE BAG SUKI DESIGN)
# 3480  (RED RETROSPOT CHARLOTTE BAG)
# 3481  (CHARLOTTE BAG PINK POLKADOT)
# 3482     (STRAWBERRY CHARLOTTE BAG)
# 3483       (WOODLAND CHARLOTTE BAG)
#
#                                             consequents   support  confidence  \
# 0                                      (DOTCOM POSTAGE)  0.010459    0.211518
# 1                              (6 RIBBONS RUSTIC CHARM)  0.010459    0.285311
# 2                              (JAM MAKING SET PRINTED)  0.012219    0.247120
# 3                              (6 RIBBONS RUSTIC CHARM)  0.012219    0.203098
# 4                            (JAM MAKING SET WITH JARS)  0.010718    0.216754
# ...

# %%
rules = rules.sort_values(
    by='lift',
    ascending=False
)

rules.head(10)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %% [markdown]
# # Evaluation
#
# Evaluasi dilakukan menggunakan:
#
# - Support
# - Confidence
# - Lift
#
# Rule dengan confidence di atas 80% dianggap memiliki hubungan yang kuat.
#
# Nilai lift lebih dari 1 menunjukkan adanya hubungan positif antar produk.

# %%
rules.sort_values(
    by='confidence',
    ascending=False
).head(10)
# Out:
#                                             antecedents  \
# 1834       (SUKI  SHOULDER BAG, JAM MAKING SET PRINTED)
# 3163  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 3457  (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK ...
# 3233  (ROSES REGENCY TEACUP AND SAUCER , REGENCY CAK...
# 2010  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 3121  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 1926      (SUKI  SHOULDER BAG, JUMBO BAG RED RETROSPOT)
# 3232  (GREEN REGENCY TEACUP AND SAUCER, REGENCY CAKE...
# 2004  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
# 3261  (JUMBO BAG PINK POLKADOT, JUMBO  BAG BAROQUE B...
#
#                              consequents  antecedent support  \
# 1834                    (DOTCOM POSTAGE)            0.011287
# 3163       (RED RETROSPOT CHARLOTTE BAG)            0.013617
# 3457       (RED RETROSPOT CHARLOTTE BAG)            0.011494
# 3233   (GREEN REGENCY TEACUP AND SAUCER)            0.017138
# ...

# %%
rules_positive = rules[rules['lift'] > 1]

rules_positive[['antecedents',
                'consequents',
                'support',
                'confidence',
                'lift']].sort_values(
                    by='lift',
                    ascending=False
                ).head(10)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
top_rules = rules.head(10)

plt.figure(figsize=(10,5))

plt.bar(
    range(len(top_rules)),
    top_rules['confidence']
)

plt.title("Top 10 Confidence Rules")

plt.show()

# %% [markdown]
# # Conclusion
#
# Berdasarkan hasil analisis menggunakan algoritma Apriori pada dataset Online Retail, ditemukan beberapa pola pembelian produk yang sering terjadi secara bersamaan.
#
# Aturan asosiasi yang dihasilkan memiliki nilai confidence di atas 80% dan nilai lift lebih dari 1 sehingga menunjukkan hubungan yang kuat antar produk.
#
# Hasil analisis dapat digunakan sebagai dasar strategi promosi, bundling produk, dan penempatan produk yang lebih efektif.

# %%
top_products = (
    df['Description']
    .value_counts()
    .head(200)
    .index
)

df_top = df[df['Description'].isin(top_products)]

# %%
basket = (
    df_top.groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum()
          .unstack()
          .fillna(0)
)
    
basket_sets = (basket > 0).astype(int)

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(
    basket_sets,
    min_support=0.01,
    use_colnames=True,
    low_memory=True
)

# %%
rules[['antecedents',
       'consequents',
       'support']]
# Out:
#                         antecedents  \
# 0          (6 RIBBONS RUSTIC CHARM)
# 1                  (DOTCOM POSTAGE)
# 2          (6 RIBBONS RUSTIC CHARM)
# 3          (JAM MAKING SET PRINTED)
# 4          (6 RIBBONS RUSTIC CHARM)
# ...                             ...
# 3479    (CHARLOTTE BAG SUKI DESIGN)
# 3480  (RED RETROSPOT CHARLOTTE BAG)
# 3481  (CHARLOTTE BAG PINK POLKADOT)
# 3482     (STRAWBERRY CHARLOTTE BAG)
# 3483       (WOODLAND CHARLOTTE BAG)
#
#                                             consequents   support
# 0                                      (DOTCOM POSTAGE)  0.010459
# 1                              (6 RIBBONS RUSTIC CHARM)  0.010459
# 2                              (JAM MAKING SET PRINTED)  0.012219
# 3                              (6 RIBBONS RUSTIC CHARM)  0.012219
# 4                            (JAM MAKING SET WITH JARS)  0.010718
# ...                                                 ...       ...
# ...

# %%
rules[['antecedents',
       'consequents',
       'confidence']]
# Out:
#                         antecedents  \
# 0          (6 RIBBONS RUSTIC CHARM)
# 1                  (DOTCOM POSTAGE)
# 2          (6 RIBBONS RUSTIC CHARM)
# 3          (JAM MAKING SET PRINTED)
# 4          (6 RIBBONS RUSTIC CHARM)
# ...                             ...
# 3479    (CHARLOTTE BAG SUKI DESIGN)
# 3480  (RED RETROSPOT CHARLOTTE BAG)
# 3481  (CHARLOTTE BAG PINK POLKADOT)
# 3482     (STRAWBERRY CHARLOTTE BAG)
# 3483       (WOODLAND CHARLOTTE BAG)
#
#                                             consequents  confidence
# 0                                      (DOTCOM POSTAGE)    0.211518
# 1                              (6 RIBBONS RUSTIC CHARM)    0.285311
# 2                              (JAM MAKING SET PRINTED)    0.247120
# 3                              (6 RIBBONS RUSTIC CHARM)    0.203098
# 4                            (JAM MAKING SET WITH JARS)    0.216754
# ...                                                 ...         ...
# ...

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(
    frequent_itemsets,
    metric='lift',
    min_threshold=1
)

rules.sort_values(
    by='lift',
    ascending=False
)[['antecedents',
   'consequents',
   'support',
   'confidence',
   'lift']].head(10)
# Out:
#                                             antecedents  \
# 3461  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3476  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 3477  (CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOT...
# 3460  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3468  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 3469  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3459  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG PI...
# 3478  (STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE ...
# 3470  (CHARLOTTE BAG PINK POLKADOT, CHARLOTTE BAG SU...
# 3467  (RED RETROSPOT CHARLOTTE BAG, STRAWBERRY CHARL...
#
#                                             consequents   support  confidence  \
# 3461  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...  0.010562    0.607143
# 3476  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...  0.010562    0.538259
# 3477  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...  0.010562    0.516456
# ...

# %%
rules.sort_values(
    by='lift',
    ascending=False
).head(10)
# Out:
#                                             antecedents  \
# 3461  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3476  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 3477  (CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOT...
# 3460  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3468  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...
# 3469  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...
# 3459  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG PI...
# 3478  (STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE ...
# 3470  (CHARLOTTE BAG PINK POLKADOT, CHARLOTTE BAG SU...
# 3467  (RED RETROSPOT CHARLOTTE BAG, STRAWBERRY CHARL...
#
#                                             consequents  antecedent support  \
# 3461  (CHARLOTTE BAG PINK POLKADOT, STRAWBERRY CHARL...            0.017397
# 3476  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...            0.019623
# 3477  (RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG SU...            0.020451
# ...
